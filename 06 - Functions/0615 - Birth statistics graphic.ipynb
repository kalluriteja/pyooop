# %%
xs = []
ys = []

name = "Jose"
gender = "M"
state = "CA"

with open("../data/names.csv", "r") as file:
    counter = 0
    for line in file:
        counter = counter + 1
        line_split = line.strip().split(",")
        if line_split[1] == name and line_split[3] == gender and line_split[4] == state:
            xs.append(int(line_split[2]))
            ys.append(int(line_split[5]))
print(xs)
print(ys)
# Out:
# [1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]
# [16, 17, 23, 22, 33, 40, 52, 47, 86, 85, 140, 121, 151, 196, 221, 192, 209, 287, 325, 246, 257, 201, 168, 137, 122, 117, 116, 104, 116, 122, 113, 113, 137, 153, 187, 195, 195, 291, 302, 301, 395, 374, 367, 442, 495, 472, 469, 585, 572, 665, 754, 655, 743, 783, 854, 918, 922, 953, 1133, 1158, 1366, 1431, 1575, 1705, 1939, 2083, 2344, 2322, 2510, 2681, 2973, 3196, 3097, 2836, 2906, 3119, 3066, 3307, 3545, 4178, 4911, 5032, 5062, 5016, 4767, 4573, 4645, 4154, 4279, 3867, 3803, 3423, 3554, 3377, 3385, 3195, 3096, 2848, 2570, 2172, 1930, 1674, 1575, 1347, 1318]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(xs, ys)
plt.show()
